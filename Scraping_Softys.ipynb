# %% [markdown]
# <a href="https://colab.research.google.com/github/Aromer9/Scraping_BeautifulSoup.ipynb/blob/main/Scraping_Softys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Librerías

# %%
from bs4 import BeautifulSoup
import requests
import urllib.parse
import pandas as pd
import random
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Jumbo

# %%
#Categoría papel higiénico
url = 'https://www.jumbo.cl/limpieza/papeles-hogar/papel-higienico'
page = requests.get(url)
bs_page = BeautifulSoup(page.text, "html.parser")

# %%
bs_page
# Out:
# <!DOCTYPE html>
# ...

# %%
urls = [
    'https://www.jumbo.cl/limpieza/papeles-hogar/papel-higienico'
    ]
urls
# Out:
# ['https://www.jumbo.cl/limpieza/papeles-hogar/papel-higienico']

# %%
texto = []
for url in urls:
  page = requests.get(url)
  bs_page = BeautifulSoup(page.text, "html.parser")
  #print(page)
  for i in bs_page.find("span", {"class": "prices-main-price"}).children:
  #  precio = None
  #  nombre = None
  #  if precio is None:
      #precio = i.text.strip()
  #    print(i.text.strip())
    #if nombre is None:
      #nombre = url
    #if precio is not None and nombre is not None:
    #  texto.append((nombre, precio))
    #  precio = None
    #  nombre = None
    #  break
    #print(url)
    #print(precio) class="product-card-name"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-b46857b51e03> in <cell line: 2>()
#       4   bs_page = BeautifulSoup(page.text, "html.parser")
#       5   #print(page)
# ----> 6   for i in bs_page.find("class", {"class": "prices-main-price"}).children:
#       7     print(i.text.strip())
#       8   #  precio = None
#
# AttributeError: 'NoneType' object has no attribute 'children'

# %%
texto
# Out:
# []
