# %% [markdown]
# <a href="https://colab.research.google.com/github/Aromer9/Scraping_BeautifulSoup.ipynb/blob/main/Scraping_BeautifulSoup.ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests
import urllib.parse
import pandas as pd
import random

# %%
# pagina principal
url = 'https://www.frest.cl/producto/522-acelga-1-kg'
page = requests.get(url)
bs_page = BeautifulSoup(page.text, "html.parser")


    ## Guardar url y precio
    ##class="text-gray-600 line-through" Identificaor precio Cebolla

# %%
#bs_page

# %%
#precio = bs_page.find("span", {"class": "text-gray-600 line-through"})
#precio

# %%
#pd_qas = pd.DataFrame(columns=[url, precio])
#pd_qas[url] = url
#pd_qas

# %%
urls = [
    'https://www.frest.cl/producto/38-pimiento-rojo-un',
    'https://www.frest.cl/producto/33-papas-1-kg',
    'https://www.frest.cl/producto/59-limon-1-kg',
    'https://www.frest.cl/producto/2152-tomate-2a-seleccion-1-kg',
    'https://www.frest.cl/producto/30-lechuga-hidroponica-espanola-un',
    'https://www.frest.cl/producto/60-manzana-fuji-1-kg',
    'https://www.frest.cl/producto/377-platano-maduro-1-kg',
    'https://www.frest.cl/producto/49-zanahoria-1-kg',
    'https://www.frest.cl/producto/1900-cebolla-1-kg',
    'https://www.frest.cl/producto/50-zapallo-trozo',
    'https://www.frest.cl/producto/19-cebollin-3-un',
    'https://www.frest.cl/producto/994-palta-hass-chilena-1-kg',
    'https://www.frest.cl/producto/66-naranja-1-kg'

    ]
urls
# Out:
# ['https://www.frest.cl/producto/38-pimiento-rojo-un',
#  'https://www.frest.cl/producto/33-papas-1-kg',
#  'https://www.frest.cl/producto/59-limon-1-kg',
#  'https://www.frest.cl/producto/2152-tomate-2a-seleccion-1-kg',
#  'https://www.frest.cl/producto/30-lechuga-hidroponica-espanola-un',
#  'https://www.frest.cl/producto/60-manzana-fuji-1-kg',
#  'https://www.frest.cl/producto/377-platano-maduro-1-kg',
#  'https://www.frest.cl/producto/49-zanahoria-1-kg',
#  'https://www.frest.cl/producto/1900-cebolla-1-kg',
#  'https://www.frest.cl/producto/50-zapallo-trozo',
#  'https://www.frest.cl/producto/19-cebollin-3-un',
#  'https://www.frest.cl/producto/994-palta-hass-chilena-1-kg',
#  'https://www.frest.cl/producto/66-naranja-1-kg']

# %%
texto = []
for url in urls:
  page = requests.get(url)
  bs_page = BeautifulSoup(page.text, "html.parser")
  #print(page)
  for i in bs_page.find("span", {"class": "text-gray-600 line-through"}).children:
    precio = None
    nombre = None
    if precio is None:
      precio = i.text.strip()
    if nombre is None:
      nombre = url
    if precio is not None and nombre is not None:
      texto.append((nombre, precio))
      precio = None
      nombre = None
      break
    #print(url)
    #print(precio)

# %%
texto
# Out:
# [('https://www.frest.cl/producto/38-pimiento-rojo-un', '$1.590'),
#  ('https://www.frest.cl/producto/33-papas-1-kg', '$2.990'),
#  ('https://www.frest.cl/producto/59-limon-1-kg', '$1.590'),
#  ('https://www.frest.cl/producto/2152-tomate-2a-seleccion-1-kg', '$1.690'),
#  ('https://www.frest.cl/producto/30-lechuga-hidroponica-espanola-un',
#   '$1.690'),
#  ('https://www.frest.cl/producto/60-manzana-fuji-1-kg', '$2.390'),
#  ('https://www.frest.cl/producto/377-platano-maduro-1-kg', '$1.590'),
#  ('https://www.frest.cl/producto/49-zanahoria-1-kg', '$990'),
#  ('https://www.frest.cl/producto/1900-cebolla-1-kg', '$1.990'),
#  ('https://www.frest.cl/producto/50-zapallo-trozo', '$1.290'),
#  ('https://www.frest.cl/producto/19-cebollin-3-un', '$990'),
#  ('https://www.frest.cl/producto/994-palta-hass-chilena-1-kg', '$4.790'),
#  ('https://www.frest.cl/producto/66-naranja-1-kg', '$1.490')]

# %%
pd_qas = pd.DataFrame(texto, columns=['nombre', 'precio'])
pd_qas
# Out:
#                                                nombre  precio
# 0   https://www.frest.cl/producto/38-pimiento-rojo-un  $1.590
# 1         https://www.frest.cl/producto/33-papas-1-kg  $2.990
# 2         https://www.frest.cl/producto/59-limon-1-kg  $1.590
# 3   https://www.frest.cl/producto/2152-tomate-2a-s...  $1.690
# 4   https://www.frest.cl/producto/30-lechuga-hidro...  $1.690
# 5   https://www.frest.cl/producto/60-manzana-fuji-...  $2.390
# 6   https://www.frest.cl/producto/377-platano-madu...  $1.590
# 7     https://www.frest.cl/producto/49-zanahoria-1-kg    $990
# 8     https://www.frest.cl/producto/1900-cebolla-1-kg  $1.990
# 9      https://www.frest.cl/producto/50-zapallo-trozo  $1.290
# 10     https://www.frest.cl/producto/19-cebollin-3-un    $990
# 11  https://www.frest.cl/producto/994-palta-hass-c...  $4.790
# 12      https://www.frest.cl/producto/66-naranja-1-kg  $1.490
